# %% [markdown]
# ### DATA ANALYZATION

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Sample - Superstore - Sample - Superstore.csv")

# %% [markdown]
# ### ROWS AND COLUMNS

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.value_counts()
# Out:
# Row ID  Order ID        Order Date  Ship Date   Ship Mode       Customer ID  Customer Name     Segment    Country        City             State       Postal Code  Region  Product ID       Category         Sub-Category  Product Name                                                               Sales     Quantity  Discount  Profit
# 1       CA-2016-152156  11/8/2016   11/11/2016  Second Class    CG-12520     Claire Gute       Consumer   United States  Henderson        Kentucky    42420        South   FUR-BO-10001798  Furniture        Bookcases     Bush Somerset Collection Bookcase                                          261.9600  2         0.00       41.9136     1
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df.sort_values('Order Date').tail()
# df.sort_values('Order Date').head()
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 5091    5092  CA-2017-156720 2017-12-30  1/3/2018  Standard Class    JM-15580
# 908      909  CA-2017-143259 2017-12-30  1/3/2018  Standard Class    PO-18865
# 907      908  CA-2017-143259 2017-12-30  1/3/2018  Standard Class    PO-18865
# 1296    1297  CA-2017-115427 2017-12-30  1/3/2018  Standard Class    EB-13975
# 906      907  CA-2017-143259 2017-12-30  1/3/2018  Standard Class    PO-18865
#
#           Customer Name    Segment        Country           City  ...  \
# 5091      Jill Matthias   Consumer  United States       Loveland  ...
# 908   Patrick O'Donnell   Consumer  United States  New York City  ...
# 907   Patrick O'Donnell   Consumer  United States  New York City  ...
# 1296         Erica Bern  Corporate  United States      Fairfield  ...
# 906   Patrick O'Donnell   Consumer  United States  New York City  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
print(df['Order Date'].head())
# Out:
# 0   2016-11-08
# 1   2016-11-08
# 2   2016-06-12
# 3   2015-10-11
# 4   2015-10-11
# Name: Order Date, dtype: datetime64[ns]

# %%
df.info()
#key eye out for order date and you understand it !
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.groupby('Category').agg({'Sales': ['mean', 'sum']})
# Out:
#                       Sales
#                        mean          sum
# Category
# Furniture        349.834887  741999.7953
# Office Supplies  119.324101  719047.0320
# Technology       452.709276  836154.0330

# %%
count_by_category = df.groupby('Category')['Product Name'].count().reset_index(name='count')
print(count_by_category)
# Out:
#           Category  count
# 0        Furniture   2121
# 1  Office Supplies   6026
# 2       Technology   1847

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64
